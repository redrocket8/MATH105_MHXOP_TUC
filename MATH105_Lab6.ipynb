# %% [markdown]
# <a href="https://colab.research.google.com/github/redrocket8/MATH105_MHXOP_TUC/blob/main/MATH105_Lab6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Λήψη απαιτούμενων αρχείων
# Εκτελέστε το παρακάτω κελί για να κατεβάσετε στο colab τα σχετικά αρχεία με τα παραδείγματα και τις ασκήσεις.
#
# Σε περίπτωση που τρέχετε τα παραδείγματα από το τερματικό τότε κατεβάστε τα αρχεία **example.txt** και **vathmoi.txt** από το eclass στον φάκελο εργασίας σας.

# %%
# @title
import urllib.request
file1_raw_url = "https://raw.githubusercontent.com/redrocket8/MATH105_MHXOP_TUC/main/example.txt"
local_file1_path = "/content/example.txt"
urllib.request.urlretrieve(file1_raw_url, local_file1_path)

file2_raw_url="https://github.com/redrocket8/MATH105_MHXOP_TUC/blob/f595e22fa58b836e75cae189813e5af105d4d9eb/vathmoi.data"
local_file2_path = "/content/vathmoi.data"
urllib.request.urlretrieve(file2_raw_url, local_file2_path)
# Out:
# ('/content/vathmoi.data', <http.client.HTTPMessage at 0x7928232be4d0>)

# %% [markdown]
# # ΜΑΘ105-Εργαστήριο 6
# #**Δημιουργία και προσπέλαση αρχείων στην Python**
#
# ## **Εισαγωγή**
#
# Η δημιουργία και η προσπέλαση αρχείων είναι κρίσιμες λειτουργίες στον προγραμματισμό, που επιτρέπουν στους προγραμματιστές να αποθηκεύουν και να ανακτούν δεδομένα από εξωτερικά αρχεία. Στη γλώσσα προγραμματισμού Python, η διαχείριση αρχείων γίνεται με τη χρήση της συνάρτησης `open()`.
#
# Κατά το άνοιγμα ενός **αρχείου**, προσδιορίζουμε το όνομά του και τον τρόπο ανοίγματος, που καθορίζει εάν θα διαβάζουμε ('r'), θα γράφουμε ('w'), ή θα προσθέτουμε περιεχόμενο ('a'). Είναι σημαντικό να κλείνουμε το αρχείο μετά τη χρήση, χρησιμοποιώντας τη μέθοδο `close()`.
#
# Για την ανάγνωση των περιεχομένων ενός αρχείου, χρησιμοποιούμε μεθόδους όπως `read()`, `readline()` ή `readlines()`. Η εγγραφή σε ένα αρχείο γίνεται με τη μέθοδο `write()`.
#
# Στην Python, η διαχείριση αρχείων μας παρέχει την ευελιξία να διαχειριζόμαστε δεδομένα σε μια ποικιλία μορφών, πετυχαίνοντας την αποτελεσματική αποθήκευση και ανάκτηση πληροφοριών από αρχεία.
#
# ## **Άνοιγμα αρχείου**
#
# ```python
# open('filename', 'mode')
# ```
# `'filename'`: Το όνομα του αρχείου που θέλουμε να ανοίξουμε.
#
# `'mode'`: Καθορίζει τον τρόπο προσπέλασης του αρχείου.
#
#
# *   `'filename'`: Το όνομα του αρχείου που θέλουμε να ανοίξουμε.
# *   `'mode'`: Καθορίζει τον τρόπο προσπέλασης του αρχείου.
#     * `'r'` Ανοίγει ένα αρχείο κειμένου για ανάγνωση (read),
#     * `'w'` Ανοίγει ένα αρχείο κειμένου για γράψιμο (write). Αν το αρχείο υπάρχει τα περιεχομενά του διαγράφονται.
#     * `'a'` Ανοίγει ένα αρχείο κειμένου για προσθήκη (append), δηλαδή προσθέτει τα νέα δεδομένα στο τέλος του αρχείου. Αν το αρχείο δεν υπάρχει το δημιουργεί.
#
#
#
#
#
# ### $\color{green}{\text{Παράδειγμα 1ο}}$:

# %%
file_name = 'example.txt'
file = open(file_name, 'r')  # Opens 'example.txt' in read mode.
# Always remember to close the file after use.
file.close()

# %% [markdown]
# ## **Άνοιγμα αρχείου κειμένου για διάβασμα των περιεχομένων του**
# Μόλις ένα αρχείο είναι ανοιχτό, μπορούμε να διαβάσουμε τα περιεχομενά του χρησιμοποιώντας διάφορες μεθόδους
#
# *   `read()`: Διαβάζει ολόκληρο το αρχείο.
# *   `readline()` Διάβάζει μόνο μία γραμμή.
# *   `readlines()` Διαβάζει όλες τις γραμμές του αρχείου και τις αποθηκεύει σε μία λίστα

# %% [markdown]
# ### $\color{green}{\text{Παράδειγμα 2ο}}$:

# %%
#code_62.py

file1 = open('example.txt', 'r') # we open the file in read ('r') mode.
content = file1.read() # read the entire file.
print(content)

file1.close()
# Out:
# Εισαγωγή στη Μηχανική Μάθηση
#
# Η Μηχανική Μάθηση είναι ένα συναρπαστικό πεδίο στον χώρο της επιστήμης των υπολογιστών. Στον πυρήνα της Μηχανικής Μάθησης βρίσκεται η ιδέα ότι οι υπολογιστές μπορούν να μάθουν από δεδομένα και εμπειρίες, χωρίς να χρειάζεται να προγραμματίζονται εκ των προτέρων.
#
# Βασικές Έννοιες:
#
# 1. **Υπολογιστική Δύναμη:** Η Μηχανική Μάθηση επιτρέπει στους υπολογιστές να αντλούν συμπεράσματα από δεδομένα και να λαμβάνουν αποφάσεις χωρίς να προγραμματίζονται αυστηρά.
#
# 2. **Αλγόριθμοι Μάθησης:** Οι αλγόριθμοι μάθησης είναι τα εργαλεία που επιτρέπουν στους υπολογιστές να μαθαίνουν από τα δεδομένα. Περιλαμβάνουν αλγόριθμους όπως οι Νευρωνικοί Δίκτυα, οι Δέντρα Αποφάσεων και οι Μεθόδοι Συσταδοποίησης.
#
# 3. **Εφαρμογές:** Η Μηχανική Μάθηση χρησιμοποιείται σε πολλούς τομείς, όπως η Επεξεργασία Φυσικής Γλώσσας, η Αναγνώριση Εικόνας, η Πρόβλεψη Δεδομένων και πολλά άλλα.
#
# ...

# %% [markdown]
# ### $\color{green}{\text{Παράδειγμα 3ο}}$:

# %%
#code_63.py

file = open('example.txt', 'r')
content = file.readline() # read only one line
content = file.readline()
content = file.readline()
print(content)

file.close()
# Out:
# Η Μηχανική Μάθηση είναι ένα συναρπαστικό πεδίο στον χώρο της επιστήμης των υπολογιστών. Στον πυρήνα της Μηχανικής Μάθησης βρίσκεται η ιδέα ότι οι υπολογιστές μπορούν να μάθουν από δεδομένα και εμπειρίες, χωρίς να χρειάζεται να προγραμματίζονται εκ των προτέρων.

# %% [markdown]
# ### $\color{green}{\text{Παράδειγμα 4ο}}$:
# Ο παρακάτω κώδικας ανοίγει το αρχείο **example.txt** σε read mode, διαβάζει τις γραμμές του αρχείου και τις αποθηκεύει σε μία λίστα

# %%
#code_64a.py

file1 = open('example.txt', 'r')
content = file1.readlines() # read all the lines of the file and save them to a list
print(content)

file1.close()
# Out:
# ['Εισαγωγή στη Μηχανική Μάθηση\n', '\n', 'Η Μηχανική Μάθηση είναι ένα συναρπαστικό πεδίο στον χώρο της επιστήμης των υπολογιστών. Στον πυρήνα της Μηχανικής Μάθησης βρίσκεται η ιδέα ότι οι υπολογιστές μπορούν να μάθουν από δεδομένα και εμπειρίες, χωρίς να χρειάζεται να προγραμματίζονται εκ των προτέρων.\n', '\n', 'Βασικές Έννοιες:\n', '\n', '1. **Υπολογιστική Δύναμη:** Η Μηχανική Μάθηση επιτρέπει στους υπολογιστές να αντλούν συμπεράσματα από δεδομένα και να λαμβάνουν αποφάσεις χωρίς να προγραμματίζονται αυστηρά.\n', '\n', '2. **Αλγόριθμοι Μάθησης:** Οι αλγόριθμοι μάθησης είναι τα εργαλεία που επιτρέπουν στους υπολογιστές να μαθαίνουν από τα δεδομένα. Περιλαμβάνουν αλγόριθμους όπως οι Νευρωνικοί Δίκτυα, οι Δέντρα Αποφάσεων και οι Μεθόδοι Συσταδοποίησης.\n', '\n', '3. **Εφαρμογές:** Η Μηχανική Μάθηση χρησιμοποιείται σε πολλούς τομείς, όπως η Επεξεργασία Φυσικής Γλώσσας, η Αναγνώριση Εικόνας, η Πρόβλεψη Δεδομένων και πολλά άλλα.\n', '\n', 'Αυτό το αρχείο αποτελεί μια εισαγωγή στον κόσμο 
# ...

# %% [markdown]
# Εναλλακτικά, μπορούμε να εφαρμόσουμε και τον παρακάτω τρόπο για να διαβάσουμε το αρχείο

# %%
#code_64b.py

content=[] # creat an empty list

with open('example.txt', 'r') as file1: # open the file in read ('r') mode
    for line in file1:                  # itterate the lines of the file
        content.append(line.strip())           # save each line into the list

print(content)
# Out:
# ['Εισαγωγή στη Μηχανική Μάθηση', '', 'Η Μηχανική Μάθηση είναι ένα συναρπαστικό πεδίο στον χώρο της επιστήμης των υπολογιστών. Στον πυρήνα της Μηχανικής Μάθησης βρίσκεται η ιδέα ότι οι υπολογιστές μπορούν να μάθουν από δεδομένα και εμπειρίες, χωρίς να χρειάζεται να προγραμματίζονται εκ των προτέρων.', '', 'Βασικές Έννοιες:', '', '1. **Υπολογιστική Δύναμη:** Η Μηχανική Μάθηση επιτρέπει στους υπολογιστές να αντλούν συμπεράσματα από δεδομένα και να λαμβάνουν αποφάσεις χωρίς να προγραμματίζονται αυστηρά.', '', '2. **Αλγόριθμοι Μάθησης:** Οι αλγόριθμοι μάθησης είναι τα εργαλεία που επιτρέπουν στους υπολογιστές να μαθαίνουν από τα δεδομένα. Περιλαμβάνουν αλγόριθμους όπως οι Νευρωνικοί Δίκτυα, οι Δέντρα Αποφάσεων και οι Μεθόδοι Συσταδοποίησης.', '', '3. **Εφαρμογές:** Η Μηχανική Μάθηση χρησιμοποιείται σε πολλούς τομείς, όπως η Επεξεργασία Φυσικής Γλώσσας, η Αναγνώριση Εικόνας, η Πρόβλεψη Δεδομένων και πολλά άλλα.', '', 'Αυτό το αρχείο αποτελεί μια εισαγωγή στον κόσμο της Μηχανικής Μάθησης. Ε
# ...

# %% [markdown]
# Οι κύριες διαφορές των δύο τρόπων είναι:
#
# 1.   **`readlines()` method**:
#  *   Διαβάζει όλες τις γραμμές του αρχείου και επιστρέφει μία λίστα όπου το κάθε στοιχείο της είναι μία γραμμή από το αρχείο.
#  *   Όλο το περιεχόμενο του αρχείου φορτώνεται στην μνήμη με τη μία, το οποίο μπορεί να μην είναι memory-efficient για μεγάλα αρχεία.
# 2.   **`for line in file`**:
#  *  Διαβάζει το αρχείο γραμμή κατα γραμμή δίχως να φορτώνει όλο το περιεχόμενο του αρχείου στην μνήμη.
#  * Είναι περισσότερο memory-efficient, κυρίως, για μεγάλα αρχεία αφού μόνο μία γραμμή την φορά αποθηκεύεται στην μνήμη.

# %% [markdown]
# ## **Άνοιγμα ενός αρχείου κειμένου και εγγραφή στοιχείων σε αυτό**

# %% [markdown]
# Η δημιουργία ενός νέου αρχείου γίνεται με την συνάρτηση `open()` χρησιμοποιώντας το `'w'` ως μέθοδο προσπέλασης.
# ```python
# open('filename','w')
# ```
# $\color{red}{\textbf{Προσοχή!!!}}$ Όπως ήδη αναφέραμε, αν το αρχείο υπάρχει, τα δεδομένα του θα διαγραφούν.

# %% [markdown]
# ### $\color{green}{\text{Παράδειγμα 5ο}}$:
# Ο παρακάτω κώδικας δημιουργεί ένα αρχείο με το όνομα **numbers.dat** και γράφει σε αυτο 50 φυσικούς αριθμούς καθώς και τα τετραγωνά τους σε δύο στήλες.

# %%
#code_65.py

#open a new file 'numbers.dat' in write mode and write in each line i  i^2
output_file_name='numbers.dat'

with open(output_file_name,'w') as output_file: #
    for i in range(1,101):

        output_file.write(f"{i}\t{i**2}\n")

        #print(f"{i}\t{i**2}\n")

# %% [markdown]
# ## **Προσθήκη νέων στοιχείων στο τέλος ενός αρχείου**
# Εάν θέλουμε να δημιουργήσουμε ένα νέο αρχείο, έτσι ώστε, αν το αρχείο υπάρχει ήδη, να μην διαγραφούν τα δεδομένα του χρησιμοποιούμε την συνάρτηση `open()` χρησιμοποιώντας όμως αυτή την φορά το `'a'` ως μέθοδο προσπέλασης.
# ```python
# open('filename','a')
# ```

# %% [markdown]
# ### $\color{green}{\text{Παράδειγμα 6ο}}$:
# Έστω ότι θέλουμε να προσθέσουμε στο αρχείο που δημιουργήσαμε στο *Παράδειγμα 5* στο τέλος του αρχείου, τον μέσο όρο της πρώτης στήλης και της δεύτερης.
# *   Αρχικά θα ανοίξουμε το αρχείο **numbers.dat** σε *read mode* και θα αποθηκεύσουμε τα στοιχεία της κάθε στήλης σε δύο λίστες **column1** and **column2** των οποίων θα υπολογίσουμε τον μέσο όρο των στοιχείων τους.

# %%
with open('numbers.dat','r') as input_file:
    for line in input_file:
        print(line.strip().split())
# Out:
# ['1', '1']
# ['2', '4']
# ['3', '9']
# ['4', '16']
# ['5', '25']
# ['6', '36']
# ['7', '49']
# ['8', '64']
# ['9', '81']
# ['10', '100']
# ['11', '121']
# ['12', '144']
# ['13', '169']
# ['14', '196']
# ['15', '225']
# ['16', '256']
# ['17', '289']
# ['18', '324']
# ['19', '361']
# ['20', '400']
# ['21', '441']
# ['22', '484']
# ['23', '529']
# ['24', '576']
# ['25', '625']
# ['26', '676']
# ['27', '729']
# ['28', '784']
# ['29', '841']
# ['30', '900']
# ['31', '961']
# ['32', '1024']
# ['33', '1089']
# ['34', '1156']
# ['35', '1225']
# ['36', '1296']
# ['37', '1369']
# ['38', '1444']
# ['39', '1521']
# ['40', '1600']
# ['41', '1681']
# ['42', '1764']
# ['43', '1849']
# ['44', '1936']
# ['45', '2025']
# ['46', '2116']
# ['47', '2209']
# ['48', '2304']
# ['49', '2401']
# ['50', '2500']
# ['51', '2601']
# ['52', '2704']
# ['53', '2809']
# ['54', '2916']
# ['55', '3025']
# ['56', '3136']
# ['57', '3249']
# ['58', '3364']
# ['59', '3481']
# ['60', '3600']
# ['61', '3721']
# ...

# %%
#code_66a.py
column1=[]
column2=[]
with open('numbers.dat','r') as input_file:
    for line in input_file:
        columns=line.strip().split()  # what does strip and split do?
        column1.append(float(columns[0]))
        column2.append(float(columns[1]))

sum1=0.0
sum2=0.0
for i in range(len(column1)):
    sum1=sum1+column1[i]
    sum2=sum2+column2[i]

# %% [markdown]
# *     Στην συνέχεια θα ανοίξουμε το αρχείο **numbers.dat** σε *append mode*

# %%
#code_67b.py
with open('numbers.dat','a') as output_file:
    output_file.write(f"Ο μέσος όρος των στοιχείων της πρώτης στήλης είναι {sum1/len(column1)}.\nΟ μέσος όρος της δεύτερης στήλης είναι {sum2/len(column2)}.\n")

# %% [markdown]
# ### $\color{blue}{\textbf{Άσκηση 1η}}$:

# %% [markdown]
# Δίνεται το αρχείο **[vathmoi.txt](https://github.com/redrocket8/MATH105_MHXOP_TUC/blob/f595e22fa58b836e75cae189813e5af105d4d9eb/vathmoi.txt)** το οποίο περιέχει τις βαθμολογίες 100 φοιτητών στο μάθημα *Εισαγωγή στον Προγραμματισμό Η/Υ*. Το αρχείο περιέχει δύο στήλες
#
# Στήλη1: οι Α.Μ των φοιτητών και
#
# Στήλη2: ο τελικός βαθμός του μαθήματος.
#
# Δημιουργήστε μία συνάρτηση με την ονομασία **read_vathmoi** η οποία ανοίγει το αρχείο διαβάζει τα στοιχεία της Στήλης2 και τα αποθηκεύει σε μία λίστα με το όνομα **vathmoi_list**
#
# *(Σημείωση) Εάν τρέχετε τον κωδικά σας στο παρόν workbook τότε βεβαιωθείτε ότι έχετε εκτελέσει το πρώτο κελί του workbook, διαφορετικά έαν τρέχετε τον κωδικά σας στο τερματικό τότε κατεβάστε το αρχείο από το eclass του μαθήματος και αποθηκεύστε το στον φάκελο εργασίας σας*

# %% [markdown]
# ### $\color{blue}{\textbf{Άσκηση 2η}}$:

# %% [markdown]
# Δημιουργήστε μία συνάρτηση με την ονομασία **mesos_oros** η οποία δέχεται ως όρισμα μία λίστα πραγματικών αριθμών, υπολογίζει τον μέσο όρο των στοιχείων της και γράφει το αποτέλεσμα σε ένα αρχείο με την ονομασία **output.data**. Εφαρμόστε την συνάρτηση στην λίστα της προηγούμενης άσκησης.
